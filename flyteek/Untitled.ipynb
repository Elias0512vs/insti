# %%
import pandas as pd
from io import StringIO
df = pd.read_csv("Tareas y funciones Flyteek.csv")

# %%
df
# Out:
#                                     Nombre                           Correo  \
# 0     Arqu�medes Mansueto Gavino Guti�rrez       arquimedesgavino@gmail.com
# 1              Edward Alegria Carhuanambo          edwardalegriac@gmail.com
# 2           Abel Alejandro Ramirez Ampuero          abel.aara2495@gmail.com
# 3           Abel Alejandro Ramirez Ampuero         abel.aara2495@gmail.com
# 4               Abel Edmundo Villa Mancera             abel.villa@gmail.com
# ...                                    ...                              ...
# 2496       Yenifer Milagros Sihues Galindo          yenifersihues@gmail.com
# 2497          Miguel �ngel Berrios Aguilar  berriosaguilar.miguel@gmail.com
# 2498       Juan Sebasti�n Mendoza Pinillos           sebasmenp.16@gmail.com
# 2499              Jesus Reyes Collahuacho         jesus.reyes2412@gmail.com
# 2500                   Marielita Arce Inga           arceingamari@gmail.com
#
# ...
